# %%
import pandas as pd

# %%
food = pd.read_csv('food.csv')

# %%
food
# Out:
#               Name Gender       City Frequency             Item  Spends
# 0           Nitish      M    kolkata    weekly           burger      11
# 1              anu      F    gurgaon     daily         sandwich      14
# 2            mukku      M    kolkata      once             vada      25
# 3             suri      M    kolkata   monthly            pizza      56
# 4            rajiv      M      patna     never           panner      34
# 5          barjraj      M      Delhi    weekly           Samosa      57
# 6           ramdin      F    Kolkata     daily       Manchurian     138
# 7           sharat      M     Mumbai      once    Chole Bhature     135
# 8         birender      F  Hyderabad     never        Pani Puri     179
# 9             amit      F  Bengaluru     never           Pakora     181
# 10          kushal      M    Chennai    weekly     French Fries      87
# 11           kasid      F  Ahmedabad     never            Rolls     154
# ...

# %%
food.pivot_table(index=['City','Gender'],columns='Item',values='Spends',aggfunc='mean')
# Out:
# Item              Bhelpuri  Cheese Burger  Chicken Tikka  Chole Bhature  \
# City      Gender
# Ahmedabad F          128.0            NaN            NaN            NaN
#           M            NaN            NaN            NaN            NaN
# Bengaluru F            NaN            NaN            NaN            NaN
#           M            NaN            NaN            NaN            NaN
# Chennai   F            NaN            NaN            NaN            NaN
#           M            NaN            NaN            NaN            NaN
# Delhi     M            NaN            NaN            NaN            NaN
# Ghaziabad F            NaN            NaN            NaN            NaN
#           M            NaN            NaN            NaN            NaN
# Hyderabad F            NaN            NaN            NaN            NaN
#           M            NaN            NaN            NaN            NaN
# Indore    M           66.0            NaN            NaN            NaN
# ...
